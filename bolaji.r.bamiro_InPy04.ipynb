# %%
Data={}
k=0
for i in range(1000):
    team1 = (input("Enter the team1"))
    score1 = int(input("Enter the score1"))
    team2 = (input("Enter the team2"))
    score2 = int(input("Enter the score2"))
    result= (team1, score1, team2, score2)
    team= team1
    
    def has_played (tekam,result):
        global k
        return (k)
        k=k+1

    def has_won (team,result):
        k=0
        if team==team1:
            result[1]>result[3]:
            if True:
        elif team ==team2:
            if result[3]>result[1]:
                i=i+1
                return (i)
    def has_lost (team,result):
        if team==team1:
            if result[1]<result[3]:
                i=i+1
                return (i)
        elif team ==team2:
            if result[3]<result[1]:
                i=i+1
                return (i)
    def has_drawn (team,result):
        if result[1]==result[3]:
            i=i+1
            return (i)
    def goal_for (team,result):
        if team==team1:
            return (result[1])
        elif team==team2:
            return (result[3])    
    def goal_against (team,result):
        if team==team1:
            return (result[3])
        elif team==team2:
            return (result[1])
        
        
        
        
        
        
    def get_stats (team,result):
        p=has_played (team,result)
        w=has_won (team,result)
        d=has_lost (team,result)
        l=has_drawn (team,result)
        f= goal_for (team,result)
        a=goal_against (team,result)
        gd= f-a
        pts= ((3*p)+d)
        stat=(team,p,w,d,l,f,a,gd,pts)
        return stat
    
    
    Data[team]=get_stats (team,result)
    
    p= input("Do you wanna do anything else ? Y or N")
    if p == 'N':
        break
        
        

print(Data)
# Out:
#   File "<ipython-input-14-b318709b81d8>", line 19
#     result[1]>result[3]:
#                         ^
# SyntaxError: invalid syntax

# %%
Data={}
List=[]
res=[]
rrr=[0,0,0,0,0,0,0,0]
for i in range(1000):
    team1 = (input("Enter the team1"))
    score1 = int(input("Enter the score1"))
    team2 = (input("Enter the team2"))
    score2 = int(input("Enter the score2"))
    result= (team1, score1, team2, score2)

    
    def has_played(team,result):
        return (1)
    def has_won(team,result):
        if team==team1:
            if result[1]>result[3]:
                return (1)
            else:
                return (0)
        elif team ==team2:
            if result[3]>result[1]:
                return (1)
            else:
                return (0)
        
    def has_lost(team,result):
        if team==team1:
            if result[1]<result[3]:
                return (1)
            else:
                return(0)
        elif team ==team2:
            if result[3]<result[1]:
                return (1)
            else:
                return (0)

    def has_drawn(team,result):
        if result[1]==result[3]:
            return (1)
        else:
            return (0)
    def goal_for(team,result):
        if team==team1:
            return (result[1])
        elif team==team2:
            return (result[3])    
    def goal_against(team,result):
        if team==team1:
            return (result[3])
        elif team==team2:
            return (result[1])
  


        
    p=0
    w=0
    l=0
    d=0
    a=0
    f=0
    gd=0
    pts=0
    def get_stats(team,result):
        global rrr
        p1=(has_played (team,result))
        p=p+p1
        w1=(has_won (team,result))
        w=w+w1
        d1=(has_lost (team,result))
        d=d+d1
        l1=has_drawn (team,result)
        l=l+l1
        f1= goal_for (team,result)
        f=f+f1
        a1=goal_against (team,result)
        a=a+a1
        gd= f-a
        pts= ((3*w)+d)
        ooo=[p,w,d,l,f,a,gd,pts]
        bbb=(team,ooo)
        List.append(team)
        return bbb
        

    def final(team,result):
        for j in List:
            if j==team and i>0:
                rrr=[rrr[0]+ooo[0],rrr[1]+ooo[1],rrr[2]+ooo[2],rrr[3]+ooo[3],rrr[4]+ooo[4],rrr[5]+ooo[5],rrr[6]+ooo[6],rrr[7]+ooo[7]]
                get_stats(team,result)=rrr 
                return(rrr)
            else:
                return (get_stats(team,result))
    
    
    
    
            

    res.append(tabb)
    res.append(hope)
    gg= input("Do you wanna do anything else ? Y or N")
    if gg == 'N':
        break
             

print (res)
# Out:
#   File "<ipython-input-18-05e789f1d932>", line 92
#     get_stats(team,result)=rrr
#     ^
# SyntaxError: can't assign to function call

# %%
a=("hey","y","s")
b=("d","e","g")
for j in a:
    if j== "hey":
        print("heyy")
    else:
        print ("naaaa")
# Out:
# heyy
# naaaa
# naaaa

# %%
for j in List:
            if j==team and i>0:
                rrr=[rrr[0]+ooo[0],rrr[1]+ooo[1],rrr[2]+ooo[2],rrr[3]+ooo[3],rrr[4]+ooo[4],rrr[5]+ooo[5],rrr[6]+ooo[6],rrr[7]+ooo[7]]
                return (team,rrr)       
            else:
                return (bbb)
# Out:
#   File "<ipython-input-26-f4e6e6de3bc5>", line 1
#     if team in Data == 'True':
#                               ^
# SyntaxError: unexpected EOF while parsing
